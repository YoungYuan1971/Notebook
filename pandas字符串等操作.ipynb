# %% [markdown]
# - 对字段Name进行分割为两个字段：firstName & lastName

# %%
import datetime
import pandas as pd

# %%
info = pd.read_csv('fake_info.csv')
info.head()
# Out:
#              Name               Telephone       Birth  \
# 0    James Cortez  001-063-413-7593x55230  1973-01-17
# 1    Summer Velez       624.477.9653x5953  2006-03-30
# 2    Daniel Mason    001-826-022-1771x091  1975-05-13
# 3  Lori Henderson      263.163.4209x83443  2021-04-16
# 4  Samantha Nunez         +1-314-769-6447  2015-08-07
#
#                     Company                               Position  \
# 0  Smith, Sandoval and Kirk               Doctor, general practice
# 1                 Hines PLC              Publishing rights manager
# 2           Harris and Sons  Product/process development scientist
# 3                Martin LLC                 Psychologist, clinical
# 4            Waters-Osborne            Health promotion specialist
#
#                                              Address  \
# 0    97659 Robin Highway Apt. 942\nFryland, KY 66604
# 1  5813 John Canyon Apt. 990\nWest Nathanielmouth...
# 2        1369 Dennis Summit\nPort Erikberg, DE 92989
# 3             107 John Mills\nSouth Tamara, NJ 15639
# 4  2130 Natasha Ridges Apt. 972\nWest Laurenshire...
#
#                                  Email
# 0  stephaniehutchinson@rios-hanson.org
# 1              harrisbradley@yahoo.com
# 2                teresaperez@yahoo.com
# 3                turnerdonna@lewis.net
# 4                yphillips@hotmail.com

# %%
# split有三个参数：pat-按什么分割，默认空白；n-切割几次；expand-默认False，返回序列，True返回DataFrame
names = info['Name'].str.split(pat=' ', n=1, expand=True)  
names.head()
# Out:
#           0          1
# 0     James     Cortez
# 1    Summer      Velez
# 2    Daniel      Mason
# 3      Lori  Henderson
# 4  Samantha      Nunez

# %% [markdown]
# - 插入firstname和lastname字段到指定位置，并删除原name字段

# %%
info.insert(0, 'firstName', names[0])
info.insert(1, 'lastName', names[1])
info.drop('Name', axis=1, inplace=True)
info.head()
# Out:
#   firstName   lastName               Telephone       Birth  \
# 0     James     Cortez  001-063-413-7593x55230  1973-01-17
# 1    Summer      Velez       624.477.9653x5953  2006-03-30
# 2    Daniel      Mason    001-826-022-1771x091  1975-05-13
# 3      Lori  Henderson      263.163.4209x83443  2021-04-16
# 4  Samantha      Nunez         +1-314-769-6447  2015-08-07
#
#                     Company                               Position  \
# 0  Smith, Sandoval and Kirk               Doctor, general practice
# 1                 Hines PLC              Publishing rights manager
# 2           Harris and Sons  Product/process development scientist
# 3                Martin LLC                 Psychologist, clinical
# 4            Waters-Osborne            Health promotion specialist
#
#                                              Address  \
# 0    97659 Robin Highway Apt. 942\nFryland, KY 66604
# 1  5813 John Canyon Apt. 990\nWest Nathanielmouth...
# 2        1369 Dennis Summit\nPort Erikberg, DE 92989
# 3             107 John Mills\nSouth Tamara, NJ 15639
# 4  2130 Natasha Ridges Apt. 972\nWest Laurenshire...
#
#                                  Email
# 0  stephaniehutchinson@rios-hanson.org
# 1              harrisbradley@yahoo.com
# 2                teresaperez@yahoo.com
# 3                turnerdonna@lewis.net
# 4                yphillips@hotmail.com

# %% [markdown]
# - 从Email中提取域名（Series字符串操作支持正则表达式）

# %%
info['Domain'] = info['Email'].str.extract('@(.*)')
info
# Out:
#       firstName   lastName               Telephone       Birth  \
# 0         James     Cortez  001-063-413-7593x55230  1973-01-17
# 1        Summer      Velez       624.477.9653x5953  2006-03-30
# 2        Daniel      Mason    001-826-022-1771x091  1975-05-13
# 3          Lori  Henderson      263.163.4209x83443  2021-04-16
# 4      Samantha      Nunez         +1-314-769-6447  2015-08-07
# ...         ...        ...                     ...         ...
# 99995     Julie   Williams    001-460-209-6358x986  2017-12-05
# 99996   Rebecca     Willis     +1-287-065-1465x355  2018-09-06
# 99997     Janet    Gregory         +1-031-438-3129  1979-04-26
# 99998     Danny      Burns        216.960.0254x922  1996-10-26
# 99999   Michael   Martinez            187-120-1526  1997-05-13
#
#                            Company                               Position  \
# 0         Smith, Sandoval and Kirk               Doctor, general practice
# 1                        Hines PLC              Publishing rights manager
# 2                  Harris and Sons  Product/process development scientist
# 3                       Martin LLC                 Psychologist, clinical
# 4                   Waters-Osborne            Health promotion specialist
# ...                            ...                                    ...
# 99995              Schroeder-Young                          Stage manager
# 99996   Williams, Hodge and Weaver                        Systems analyst
# 99997  Mitchell, Pena and Williams                                 Lawyer
# 99998                 Wagner Group                  Forensic psychologist
# 99999                Escobar-Moore       Training and development officer
#
#                                                  Address  \
# 0        97659 Robin Highway Apt. 942\nFryland, KY 66604
# 1      5813 John Canyon Apt. 990\nWest Nathanielmouth...
# 2            1369 Dennis Summit\nPort Erikberg, DE 92989
# 3                 107 John Mills\nSouth Tamara, NJ 15639
# 4      2130 Natasha Ridges Apt. 972\nWest Laurenshire...
# ...                                                  ...
# 99995  32740 Anderson Junction Suite 346\nJohnsonfurt...
# 99996       5302 Alison Throughway\nNorth Erin, TX 26478
# 99997   625 Wade Route Suite 688\nLake Barbara, MI 65061
# 99998        791 John Ports\nEast Jeremiahbury, DE 49247
# 99999  53087 Hood Summit Suite 775\nEast Leahbury, NY...
#
#                                      Email            Domain
# 0      stephaniehutchinson@rios-hanson.org   rios-hanson.org
# 1                  harrisbradley@yahoo.com         yahoo.com
# 2                    teresaperez@yahoo.com         yahoo.com
# 3                    turnerdonna@lewis.net         lewis.net
# 4                    yphillips@hotmail.com       hotmail.com
# ...                                    ...               ...
# 99995                  nmiller@hotmail.com       hotmail.com
# 99996              kbrock@wood-walter.info  wood-walter.info
# 99997                    thorton@gmail.com         gmail.com
# 99998              sarahmassey@hotmail.com       hotmail.com
# 99999                   ronald95@gmail.com         gmail.com
#
# [100000 rows x 9 columns]

# %% [markdown]
# - 计算每个人的年龄，并筛选出年龄在35-45岁，职位包含manager的数据
#     - 先将Birth转换为日期格式
#     - 再将当前日期减去Birth日期+1，得出年龄
#     - 根据年龄区间和职位包含的关键字，筛选数据

# %%
info['Birth'] = pd.to_datetime(info.Birth)
info['Age'] = datetime.datetime.now().year - info.Birth.dt.year +1
info.head()
# Out:
#   firstName   lastName               Telephone      Birth  \
# 0     James     Cortez  001-063-413-7593x55230 1973-01-17
# 1    Summer      Velez       624.477.9653x5953 2006-03-30
# 2    Daniel      Mason    001-826-022-1771x091 1975-05-13
# 3      Lori  Henderson      263.163.4209x83443 2021-04-16
# 4  Samantha      Nunez         +1-314-769-6447 2015-08-07
#
#                     Company                               Position  \
# 0  Smith, Sandoval and Kirk               Doctor, general practice
# 1                 Hines PLC              Publishing rights manager
# 2           Harris and Sons  Product/process development scientist
# 3                Martin LLC                 Psychologist, clinical
# 4            Waters-Osborne            Health promotion specialist
#
#                                              Address  \
# 0    97659 Robin Highway Apt. 942\nFryland, KY 66604
# 1  5813 John Canyon Apt. 990\nWest Nathanielmouth...
# 2        1369 Dennis Summit\nPort Erikberg, DE 92989
# 3             107 John Mills\nSouth Tamara, NJ 15639
# 4  2130 Natasha Ridges Apt. 972\nWest Laurenshire...
#
#                                  Email           Domain  Age
# 0  stephaniehutchinson@rios-hanson.org  rios-hanson.org   50
# 1              harrisbradley@yahoo.com        yahoo.com   17
# 2                teresaperez@yahoo.com        yahoo.com   48
# 3                turnerdonna@lewis.net        lewis.net    2
# 4                yphillips@hotmail.com      hotmail.com    8

# %%
filter_info = info.loc[(info.Age.between(35,45)) & info.Position.str.contains('manager')]
filter_info.head()
# Out:
#     firstName        lastName             Telephone      Birth  \
# 15    Jessica        Chambers   (282)584-7521x47057 1987-05-06
# 67     Sherri          Harris            3259346512 1983-04-21
# 158    Austin        Mcknight     894-857-4376x0470 1981-04-11
# 197  Kimberly           Nunez  001-166-070-2536x642 1978-08-18
# 233       Mr.  Joshua Lee Jr.     800-430-1906x3417 1985-04-20
#
#                           Company                   Position  \
# 15                      Doyle Inc             Quarry manager
# 67                   Lopez-Holder              Hotel manager
# 158                 Chavez-Adkins           Heritage manager
# 197  Walker, Williams and Johnson  Insurance account manager
# 233  Ortiz, Carpenter and Roberts         Purchasing manager
#
#                                            Address  \
# 15                Unit 2762 Box 3166\nDPO AP 16099
# 67     6284 Joseph Orchard\nMatthewhaven, AZ 13843
# 158        2674 Hill Vista\nPort Mallory, VT 27163
# 197     0273 Logan Squares\nLake Richard, CO 31083
# 233  684 Paul Springs\nWest Gabrielmouth, NY 69442
#
#                            Email               Domain  Age
# 15          thomas50@garcia.info          garcia.info   36
# 67    rebeccawinters@hotmail.com          hotmail.com   40
# 158  lkrause@harmon-robinson.biz  harmon-robinson.biz   42
# 197           brownkent@rios.org             rios.org   45
# 233           monica29@yahoo.com            yahoo.com   38
